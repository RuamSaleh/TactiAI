# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# In this notebook, we will perform exploratory data analysis on the tennis matches dataset to understand the features and the target variable `tactical_decision`. We will visualize the data and derive insights that can help in building a predictive model.

# %%
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualisation style
sns.set(style='whitegrid')

# %%
# Load the dataset
data = pd.read_csv('../data/tennis_matches_with_tactics.csv')

# Display the first few rows of the dataset
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2024-0339     Brisbane    Hard         32             A      20240101
# 1  2024-0339     Brisbane    Hard         32             A      20240101
# 2  2024-0339     Brisbane    Hard         32             A      20240101
# 3  2024-0339     Brisbane    Hard         32             A      20240101
# 4  2024-0339     Brisbane    Hard         32             A      20240101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     105777          2.0          NaN  ...     44.0     16.0
# 1        299     208029          1.0          NaN  ...     31.0     10.0
# 2        298     105777          2.0          NaN  ...     24.0     14.0
# 3        297     208029          1.0          NaN  ...     31.0     16.0
# 4        296     126128          NaN          NaN  ...     27.0     16.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points loser_rank  \
# ...

# %%
# Check for missing values
missing_values = data.isnull().sum()
missing_values[missing_values > 0]
# Out:
# winner_seed           1782
# winner_entry          2599
# winner_ht               19
# winner_age               1
# loser_seed            2319
# loser_entry           2358
# loser_ht                50
# loser_age                1
# minutes                238
# w_ace                   60
# w_df                    60
# w_svpt                  60
# w_1stIn                 60
# w_1stWon                60
# w_2ndWon                60
# w_SvGms                 61
# w_bpSaved               60
# w_bpFaced               60
# l_ace                   60
# l_df                    60
# l_svpt                  60
# l_1stIn                 60
# l_1stWon                60
# l_2ndWon                60
# l_SvGms                 61
# l_bpSaved               60
# l_bpFaced               60
# winner_rank             17
# winner_rank_points      17
# loser_rank              40
# loser_rank_points       40
# dtype: int64

# %%
# Visualize the distribution of the target variable
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='tactical_decision')
plt.title('Distribution of Tactical Decisions')
plt.xlabel('Tactical Decision')
plt.ylabel('Count')
plt.show()

# %%
# Visualize relationships between features and the target variable
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='tactical_decision', y='minutes')
plt.title('Minutes Played by Tactical Decision')
plt.xlabel('Tactical Decision')
plt.ylabel('Minutes')
plt.show()

# %%
numeric_data = data.select_dtypes(include=['number'])

# %%
correlation = numeric_data.corr()

# %%
# Correlation heatmap
plt.figure(figsize=(14, 10))

# Select only numeric columns
numeric_data = data.select_dtypes(include=['number'])

# Calculate correlation
correlation = numeric_data.corr()

# Plot heatmap
sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook, we performed exploratory data analysis on the tennis matches dataset. We visualized the distribution of the target variable and examined relationships between features. These insights will guide us in the data preprocessing and model training phases.
